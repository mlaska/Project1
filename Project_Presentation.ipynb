# %%
from IPython.display import Image

# %% [markdown]
# # Minneapolis Scooter data analysis

# %%
Image("Scooter.png")

# %% [markdown]
# ### Team members:
# - Michael Laska
# - David Blascyk
# - Ingris O'Connor
# - Steve Nguyen
# - Cindy Pendarvis

# %% [markdown]
# ### Project Question:
# Is the Minneapolis Scooter Pilot Program successfully serving low income populations as defined by their goals?

# %% [markdown]
# ### Goals:
# In this project we will be reviewing Scooter placement and movement over time in the city of Minneapolis. We would like to provide data correlating scooter use to low income areas via heat mapping

# %% [markdown]
# ### Data Cleanup & Exploration
# - Open Data Minneapolis csv file
#      Scooter availability
# - Census api json file
#     Poverty rate
# - GBSID csv file
#     Zip code

# %% [markdown]
# - Merged our three datasets by zip code, and created a new column describing the poverty category
#
# - Dropped all scooters that were on trails, because they didn't have a corresponding zip code
#
# - Formatted the date as mm/dd, and sorted by chronilogical order
#
# - Resetted the index

# %%
Image("Initial_Dataframe.png")

# %%
Image("Final_DataFrame.png")

# %% [markdown]
# #### Insights
#  - Readjusted analysis to account for the number of scooters availabile as a percentage.
#  - Unable to use Open Data Minneapolis api

# %% [markdown]
# #### Challenges
#  - Formatting the Coordinated Universal Time to Central Standard Time

# %% [markdown]
# #### Interesting findings
#  - All scooter data was available, and not just a sample population
#  - Lime had the majority of scooters available in Minneapolis

# %% [markdown]
# ### Data Analysis
#  - Bar graph with times
#  - Line graph
#  - possible Grapghs from Michael

# %% [markdown]
# ## Q&A
