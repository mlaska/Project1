# %%
print("hello code")

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data_complete = pd.read_csv("Scooter_Availability.csv")

data_complete.head()
# Out:
#                    PollTime CompanyName  NumberAvailable ClosestCenterlineID  \
# 0  2019-05-18T11:00:00.000Z        Lime                1               10919
# 1  2019-05-18T11:00:00.000Z        Lime                2               11310
# 2  2019-05-18T11:00:00.000Z        Lime                1               14883
# 3  2019-05-18T11:00:00.000Z        Lime                3               15822
# 4  2019-05-18T11:00:00.000Z        Lime                1               16236
#
#   ClosestCenterlineType   Neighborhood  ESRI_OID
# 0                street      Bottineau      2001
# 1                street        Holland      2002
# 2                street      Hawthorne      2003
# 3                street       Harrison      2004
# 4                street  Downtown West      2005

# %%
data_complete = pd.read_csv("Centerline_to_ZipCode.csv")

data_complete.head()
# Out:
#    OBJECTID  L_F_ADD  R_F_ADD  L_T_ADD  R_T_ADD     STREETALL F_CLASS  \
# 0         1     1601     1600     1799     1798    25TH AVE N     A40
# 1         2     2698     2699     2600     2601     50TH ST W     A30
# 2         3     2601     2600     2699     2698  GIRARD AVE N     A40
# 3         4      100      101      198      199     37TH ST E     A40
# 4         5     2000     2001     2098     2099      1ST ST S     A40
#
#          ALT_NAM1 ALT_NAM2  ZIP5_L  ZIP5_R     CITYLEFT     CITYRIGT  PREDIR  \
# 0             NaN      NaN   55411   55411  MINNEAPOLIS  MINNEAPOLIS     NaN
# 1  COUNTY ROAD 21      NaN   55410   55410  MINNEAPOLIS  MINNEAPOLIS     NaN
# 2             NaN      NaN   55411   55411  MINNEAPOLIS  MINNEAPOLIS     NaN
# 3             NaN      NaN   55409   55409  MINNEAPOLIS  MINNEAPOLIS     NaN
# 4             NaN      NaN   55454   55454  MINNEAPOLIS  MINNEAPOLIS     NaN
#
#   STREETNAME TYPE SUFDIR  SPEED_LIM HIGHWAY_NU  ALT_ID  GBSID COUNTYRIGT  \
# ...

# %%
data_complete = pd.read_csv("poverty_type.csv")

data_complete.head()
# Out:
#    Zipcode  Poverty Rate Poverty Type
# 0    55418     12.748436         High
# 1    55411     31.316104     Downtown
# 2    55405     14.252629     Downtown
# 3    55401     14.219141     Downtown
# 4    55408     15.597356         High

# %%
data_complete = pd.read_csv("scooter_complete.csv")

data_complete.head()
# Out:
#                    PollTime CompanyName  NumberAvailable ClosestCenterlineID  \
# 0  2019-05-18T11:00:00.000Z        Lime                1               10919
# 1  2019-05-18T11:00:00.000Z        Lime                2               11310
# 2  2019-05-18T11:00:00.000Z        Lime                1               14883
# 3  2019-05-18T11:00:00.000Z        Lime                3               15822
# 4  2019-05-18T11:00:00.000Z        Lime                1               16236
#
#     Neighborhood  Zipcode  Poverty Rate Poverty Type
# 0      Bottineau  55418.0     12.748436         High
# 1        Holland  55418.0     12.748436         High
# 2      Hawthorne  55411.0     31.316104     Downtown
# 3       Harrison  55405.0     14.252629     Downtown
# 4  Downtown West  55401.0     14.219141     Downtown

# %%
data_complete = pd.read_csv("Scooter_df_HrsAndDays.csv")

data_complete.head()
# Out:
#    Unnamed: 0                   PollTime CompanyName  NumberAvailable  \
# 0           0  2019-05-18 11:00:00+00:00        Lime                1
# 1           1  2019-05-18 11:00:00+00:00        Lime                2
# 2           2  2019-05-18 11:00:00+00:00        Lime                1
# 3           3  2019-05-18 11:00:00+00:00        Lime                3
# 4           4  2019-05-18 11:00:00+00:00        Lime                1
#
#    Zipcode  Poverty Rate Poverty Type  Hour  Day  Month
# 0  55418.0     12.748436         High     6   18      5
# 1  55418.0     12.748436         High     6   18      5
# 2  55411.0     31.316104     Downtown     6   18      5
# 3  55405.0     14.252629     Downtown     6   18      5
# 4  55401.0     14.219141     Downtown     6   18      5

# %%
data_complete = pd.read_csv("csvFiles/Main_Scooter_df.csv")

data_complete = data_complete.drop(['Unnamed: 0'], axis = 1)

data_complete.head()
# Out:
#                     PollTime CompanyName  NumberAvailable  Zipcode  \
# 0  2019-05-16 19:00:00+00:00        Lime                1  55412.0
# 1  2019-05-16 19:00:00+00:00        Lime                1  55412.0
# 2  2019-05-16 19:00:00+00:00        Lime                1  55418.0
# 3  2019-05-16 19:00:00+00:00        Lime                1  55408.0
# 4  2019-05-16 19:00:00+00:00        Lime                1  55417.0
#
#    Poverty Rate Poverty Type  Hour  Day  Month  Date
# 0     27.616840         High    14   16      5  5/16
# 1     27.616840         High    14   16      5  5/16
# 2     12.748436         High    14   16      5  5/16
# 3     15.597356         High    14   16      5  5/16
# 4      6.230769          Low    14   16      5  5/16

# %%
data_complete = pd.read_csv("")

data_complete.head()
